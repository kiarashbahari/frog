# %%
library(tidyverse)
library(repr)
options(repr.matrix.max.rows = 6)
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.0      ✔ purrr   1.0.0
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.5.0
# ✔ readr   2.1.3      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
r = e^0.000014997 / a
Reeves, Enright, and Fernández-Juricic (2012)
it was at room tempreture so we /a to get at 
N=N0*e^rt
# Out:
# Error in parse(text = x, srcfile = src): <text>:2:7: unexpected ','
# 1: r = e^0.000014997 / a
# 2: Reeves,
#          ^
# Traceback:

# %%
a<-1.0853567/0.6087622
r <- 0.015 / a

f1 <- function(x) 1000 * exp(x * r*a)

# Create a vector of x values
x <- seq(0, 1, by = 0.01)

# Compute the y values
y1 <- f1(x)

# Plot the function
plot(x, y1, type = "l", xlab = "x", ylab = "y",
     main = "Exponential Function",
     col = "red")

f2 <- function(x) 1000 * exp(x * r)

# Create a vector of x values
x <- seq(0, 1, by = 0.01)

# Compute the y values
y2 <- f2(x)

plot(x, y2, type = "l", xlab = "x", ylab = "y",
     main = "Exponential Function",
     col = "blue")

r*a
r
# Out:
# Plot with title “Exponential Function”
# [1] 0.015
# [1] 0.008413301
# Plot with title “Exponential Function”

# %%
f <- function(x) 10 * exp(x/10000)
df <- data.frame(x = seq(0, 1, by = 0.01), y = f(seq(0, 1, by = 0.01)))
df
# Plot the function using ggplot2
ggplot(data = df, aes(x = x, y = y)) +
  geom_line(color = "red") +
  labs(title = "Exponential Function", x = "x", y = "y")
# Out:
#     x    y
# 1   0.00 10.00000
# 2   0.01 10.00001
# 3   0.02 10.00002
# ⋮   ⋮    ⋮
# 99  0.98 10.00098
# 100 0.99 10.00099
# 101 1.00 10.00100
# plot without title

# %%
library(ggplot2)

# Define the function
f <- function(x) 100 * exp(x * 0.00841330135982023)
f(0.01)
# Create a data frame with x and y values
df <- data.frame(x = seq(0, 1, by = 0.01), y = f(seq(0, 1, by = 0.01)))
df
# Plot the function using ggplot2
ggplot(data = df, aes(x = x, y = y)) +
  geom_line(color = "red") +
  labs(title = "Exponential Function", x = "x", y = "y")
# Out:
# [1] 100.0084
#     x    y
# 1   0.00 100.0000
# 2   0.01 100.0084
# 3   0.02 100.0168
# ⋮   ⋮    ⋮
# 99  0.98 100.8279
# 100 0.99 100.8364
# 101 1.00 100.8449
# plot without title

# %%
8.41161869954827e-06
# Out:
# [1] 8.411619e-06
